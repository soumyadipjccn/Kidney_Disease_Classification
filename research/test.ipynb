# %%
def add(x:int, y:int) -> int:
    return x +y

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1d2lctJb9osjOWZi2jf4XTHUWn0iy-mDl/view?usp=sharing"

# %%
file_id = url.split("/")[-2]

# %%
file_id
# Out:
# '1d2lctJb9osjOWZi2jf4XTHUWn0iy-mDl'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-ct-scan-image.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1d2lctJb9osjOWZi2jf4XTHUWn0iy-mDl
# From (redirected): https://drive.google.com/uc?id=1d2lctJb9osjOWZi2jf4XTHUWn0iy-mDl&confirm=t&uuid=238e859b-ac26-4c3e-a713-70717ae5811d
# To: /home/user/Kidney_Disease_Classification/research/kidney-ct-scan-image.zip
# 100%|██████████| 57.7M/57.7M [00:05<00:00, 11.5MB/s]
# 'kidney-ct-scan-image.zip'
